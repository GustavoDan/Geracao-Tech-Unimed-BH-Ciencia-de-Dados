# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# # **Aula 1**

# %%
df =  pd.read_csv('datasets/Gapminder.csv', on_bad_lines='skip', delimiter=';')
df.rename(columns = {'country': 'Pais', 'continent': 'Continente', 'year': 'Ano', 'lifeExp': 'Expectativa de vida', 'pop': 'Populacao total', 'gdpPercap': 'PIB per Capta'}, inplace=True)

df.head(10)
# Out:
#           Pais Continente   Ano  Expectativa de vida  Populacao total  \
# 0  Afghanistan       Asia  1952               28.801          8425333
# 1  Afghanistan       Asia  1957               30.332          9240934
# 2  Afghanistan       Asia  1962               31.997         10267083
# 3  Afghanistan       Asia  1967               34.020         11537966
# 4  Afghanistan       Asia  1972               36.088         13079460
# 5  Afghanistan       Asia  1977               38.438         14880372
# 6  Afghanistan       Asia  1982               39.854         12881816
# 7  Afghanistan       Asia  1987               40.822         13867957
# 8  Afghanistan       Asia  1992               41.674         16317921
# 9  Afghanistan       Asia  1997               41.763         22227415
#
#    PIB per Capta
# 0     779.445314
# 1     820.853030
# 2     853.100710
# 3     836.197138
# 4     739.981106
# 5     786.113360
# 6     978.011439
# 7     852.395945
# 8     649.341395
# ...

# %%
df.shape
# Out:
# (3312, 6)

# %%
df.columns
# Out:
# Index(['Pais', 'Continente', 'Ano', 'Expectativa de vida', 'Populacao total',
#        'PIB per Capta'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pais                    object
# Continente              object
# Ano                      int64
# Expectativa de vida    float64
# Populacao total          int64
# PIB per Capta          float64
# dtype: object

# %%
df.tail(10)
# Out:
#           Pais Continente   Ano  Expectativa de vida  Populacao total  \
# 3302  Zimbabwe     Africa  1962               52.358          4277736
# 3303  Zimbabwe     Africa  1967               53.995          4995432
# 3304  Zimbabwe     Africa  1972               55.635          5861135
# 3305  Zimbabwe     Africa  1977               57.674          6642107
# 3306  Zimbabwe     Africa  1982               60.363          7636524
# 3307  Zimbabwe     Africa  1987               62.351          9216418
# 3308  Zimbabwe     Africa  1992               60.377         10704340
# 3309  Zimbabwe     Africa  1997               46.809         11404948
# 3310  Zimbabwe     Africa  2002               39.989         11926563
# 3311  Zimbabwe     Africa  2007               43.487         12311143
#
#       PIB per Capta
# 3302     527.272182
# 3303     569.795071
# 3304     799.362176
# 3305     685.587682
# 3306     788.855041
# 3307     706.157306
# 3308     693.420786
# 3309     792.449960
# ...

# %%
df.describe()
# Out:
#                Ano  Expectativa de vida  Populacao total  PIB per Capta
# count  3312.000000          3312.000000     3.312000e+03    3312.000000
# mean   1980.301630            65.246871     3.161489e+07   11317.115805
# std      16.927294            11.768412     1.041193e+08   11369.142739
# min    1950.000000            23.599000     5.941200e+04     241.165876
# 25%    1967.000000            58.337500     2.678572e+06    2514.625266
# 50%    1982.000000            69.610000     7.557218e+06    7838.505123
# 75%    1996.000000            73.657750     1.958522e+07   17357.879170
# max    2007.000000            82.670000     1.318683e+09  113523.132900

# %%
df['Continente'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
Oceania = df.loc[df['Continente'] == 'Oceania']
Oceania
# Out:
#                  Pais Continente   Ano  Expectativa de vida  Populacao total  \
# 975              Fiji    Oceania  1962               56.494           421869
# 976              Fiji    Oceania  1967               58.607           485000
# 977              Fiji    Oceania  1972               60.642           544000
# 978              Fiji    Oceania  1977               62.669           599339
# 979              Fiji    Oceania  1982               64.683           658906
# ...               ...        ...   ...                  ...              ...
# 2696  Solomon Islands    Oceania  1987               55.785           300694
# 2697  Solomon Islands    Oceania  1992               58.270           358713
# 2698  Solomon Islands    Oceania  1997               60.708           424265
# 2699  Solomon Islands    Oceania  2002               62.274           494786
# 2700  Solomon Islands    Oceania  2007               63.570           566842
#
#       PIB per Capta
# 975     2039.393277
# ...

# %%
FSU = df.loc[df['Continente'] == 'FSU']
FSU['Pais'].unique()
# Out:
# array(['Belarus', 'Kazakhstan', 'Latvia', 'Lithuania', 'Russia',
#        'Ukraine'], dtype=object)

# %%
df.groupby('Continente')['Pais'].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: Pais, dtype: int64

# %%
df.groupby('Ano')['Expectativa de vida'].mean().round(1)
# Out:
# Ano
# 1950    62.0
# 1951    65.9
# 1952    49.2
# 1953    66.7
# 1954    67.5
# 1955    67.8
# 1956    68.0
# 1957    51.6
# 1958    68.8
# 1959    68.2
# 1960    68.5
# 1961    68.9
# 1962    54.0
# 1963    69.6
# 1964    70.1
# 1965    70.3
# 1966    70.4
# 1967    56.3
# 1968    70.7
# 1969    70.7
# 1970    71.0
# 1971    71.1
# 1972    58.5
# 1973    71.5
# 1974    71.8
# 1975    71.9
# 1976    72.2
# 1977    60.4
# 1978    72.7
# 1979    73.0
# 1980    73.1
# 1981    73.3
# 1982    62.4
# 1983    73.8
# 1984    74.1
# 1985    74.1
# 1986    74.5
# 1987    64.0
# 1988    74.8
# 1989    74.9
# 1990    74.3
# 1991    74.4
# 1992    65.0
# 1993    74.3
# 1994    74.5
# 1995    74.6
# 1996    75.0
# 1997    65.9
# 1998    75.6
# 1999    75.7
# 2000    76.0
# 2001    76.3
# 2002    66.8
# 2003    76.6
# 2004    76.9
# 2005    76.7
# 2006    77.9
# 2007    67.9
# Name: Expectativa de vida, dtype: float64

# %%
df['PIB per Capta'].mean()
# Out:
# 11317.115804696648

# %%
df['PIB per Capta'].sum()
# Out:
# 37482287.5451553

# %% [markdown]
# # **Aula 2**

# %%
aracaju = pd.read_excel('datasets/Aracaju.xlsx')
fortaleza = pd.read_excel('datasets/Fortaleza.xlsx')
natal = pd.read_excel('datasets/Natal.xlsx')
recife = pd.read_excel('datasets/Recife.xlsx')
salvador = pd.read_excel('datasets/Salvador.xlsx')

df = pd.concat([aracaju, fortaleza, natal, recife, salvador])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 162   Salvador 2019-01-02   23.08    1036     2
# 163   Salvador 2019-01-02   17.66    1036     3
# 215      Natal 2019-01-02  203.84    1036     1
# 25    Salvador 2019-01-01  220.62    1035     1
# 115  Fortaleza 2019-03-02   12.23     981     3

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df['LojaID'] = df['LojaID'].astype('object')
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df['Vendas'].mean()
# Out:
# 122.61180089485458

# %%
df['Vendas'].fillna(df['Vendas'].mean(), inplace=True)

df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df['Vendas'].mean()
# Out:
# 122.61180089485458

# %%
df['Vendas'].fillna(0, inplace=True)
df.dropna(inplace=True)
df.dropna(subset=['Vendas'], inplace=True)
# Valor nulo em todas as colunas.
df.dropna(how='all', inplace=True)

# %%
df['Receita'] = df['Vendas']*df['Qtde']
# df['Qtde'] = df['Receita'] / df['Vendas']

df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1   142.00
# 1  Aracaju 2018-01-01   14.21    1522     6    85.26
# 2  Aracaju 2018-01-01   71.55    1520     1    71.55
# 3  Aracaju 2018-01-01    3.01    1521     7    21.07
# 4  Aracaju 2018-01-01   24.51    1522     8   196.08

# %%
df['Receita'].max()
# Out:
# 3544.0

# %%
df['Receita'].min()
# Out:
# 3.34

# %%
df.sort_values('Receita')
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita
# 118   Aracaju 2018-01-01    3.34    1522     1     3.34
# 65     Recife 2019-01-01    4.01     981     1     4.01
# 92   Salvador 2019-01-01    4.57    1035     1     4.57
# 92      Natal 2019-01-02    4.57    1035     1     4.57
# 95   Salvador 2019-01-01    5.13    1035     1     5.13
# ..        ...        ...     ...     ...   ...      ...
# 41      Natal 2018-05-20  835.00     852     4  3340.00
# 30      Natal 2018-10-02  856.00     853     4  3424.00
# 55      Natal 2019-01-08  859.00     854     4  3436.00
# 51      Natal 2018-01-21  859.00     852     4  3436.00
# 7       Natal 2019-03-18  886.00     853     4  3544.00
#
# [894 rows x 6 columns]

# %%
df.sort_values('Receita', ascending=False)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita
# 7       Natal 2019-03-18  886.00     853     4  3544.00
# 55      Natal 2019-01-08  859.00     854     4  3436.00
# 51      Natal 2018-01-21  859.00     852     4  3436.00
# 30      Natal 2018-10-02  856.00     853     4  3424.00
# 41      Natal 2018-05-20  835.00     852     4  3340.00
# ..        ...        ...     ...     ...   ...      ...
# 95      Natal 2019-01-02    5.13    1035     1     5.13
# 92      Natal 2019-01-02    4.57    1035     1     4.57
# 92   Salvador 2019-01-01    4.57    1035     1     4.57
# 65     Recife 2019-01-01    4.01     981     1     4.01
# 118   Aracaju 2018-01-01    3.34    1522     1     3.34
#
# [894 rows x 6 columns]

# %%
df.nlargest(3, 'Receita')
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0     853     4   3544.0
# 51  Natal 2018-01-21   859.0     852     4   3436.0
# 55  Natal 2019-01-08   859.0     854     4   3436.0

# %%
df.nsmallest(3, 'Receita')
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34    1522     1     3.34
# 65    Recife 2019-01-01    4.01     981     1     4.01
# 92     Natal 2019-01-02    4.57    1035     1     4.57

# %%
df.groupby('Cidade')['Receita'].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %% [markdown]
# # **Aula 3**

# %%
df['Data'] = df['Data'].view('int64')
df.dtypes
# Out:
# Cidade                      object
# Data                         int64
# Vendas                     float64
# LojaID                       int64
# Qtde                         int64
# Receita                    float64
# Ano_Venda                    int64
# Mes_Venda                   object
# Dia_Venda                   object
# Diferenca_Dias     timedelta64[ns]
# Trimestre_Venda              int64
# dtype: object

# %%
df['Data'] = pd.to_datetime(df['Data'])
df.dtypes
# Out:
# Cidade                      object
# Data                datetime64[ns]
# Vendas                     float64
# LojaID                       int64
# Qtde                         int64
# Receita                    float64
# Ano_Venda                    int64
# Mes_Venda                   object
# Dia_Venda                   object
# Diferenca_Dias     timedelta64[ns]
# Trimestre_Venda              int64
# dtype: object

# %%
df.groupby(df['Data'].dt.year)['Receita'].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df['Ano_Venda'] = df['Data'].dt.year

df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda Mes_Venda  \
# 12   Salvador 2019-01-01  125.05    1034     3   375.15       2019   January
# 84   Salvador 2019-01-01   22.99    1036     1    22.99       2019   January
# 91     Recife 2019-01-01  150.58     982     6   903.48       2019   January
# 10   Salvador 2019-01-01   30.97    1036     1    30.97       2019   January
# 227     Natal 2019-01-02   14.70    1035     1    14.70       2019   January
#
#      Dia_Venda Diferenca_Dias  Trimestre_Venda
# 12     Tuesday       365 days                1
# 84     Tuesday       365 days                1
# 91     Tuesday       365 days                1
# 10     Tuesday       365 days                1
# 227  Wednesday       366 days                1

# %%
df['Mes_Venda'], df['Dia_Venda'] = df['Data'].dt.month_name(), df['Data'].dt.day_name()

df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 99      Recife 2019-01-01  136.72     980     4   546.88       2019
# 86    Salvador 2019-01-01  156.47    1037     3   469.41       2019
# 48       Natal 2018-09-20  676.00     852     4  2704.00       2018
# 148   Salvador 2019-01-02   40.59    1037     3   121.77       2019
# 72   Fortaleza 2019-01-01  106.72    1003     4   426.88       2019
#
#      Mes_Venda  Dia_Venda Diferenca_Dias  Trimestre_Venda
# 99     January    Tuesday       365 days                1
# 86     January    Tuesday       365 days                1
# 48   September   Thursday       262 days                3
# 148    January  Wednesday       366 days                1
# 72     January    Tuesday       365 days                1

# %%
df['Data'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df['Data'].max()
# Out:
# Timestamp('2019-04-05 00:00:00')

# %%
df['Diferenca_Dias'] = df['Data'] - df['Data'].min()

df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda Mes_Venda  \
# 49     Recife 2019-01-01  122.55     981     1   122.55       2019   January
# 168  Salvador 2019-01-02   20.22    1036     1    20.22       2019   January
# 101   Aracaju 2018-01-01   16.62    1520     9   149.58       2018   January
# 120   Aracaju 2018-01-01    7.73    1520    10    77.30       2018   January
# 151     Natal 2019-01-02   14.63    1035     1    14.63       2019   January
#
#      Dia_Venda Diferenca_Dias  Trimestre_Venda
# 49     Tuesday       365 days                1
# 168  Wednesday       366 days                1
# 101     Monday         0 days                1
# 120     Monday         0 days                1
# 151  Wednesday       366 days                1

# %%
df['Trimestre_Venda'] = df['Data'].dt.quarter

df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda Mes_Venda  \
# 44    Salvador 2019-01-01   43.26    1037     2    86.52       2019   January
# 31   Fortaleza 2019-01-01   23.46    1002     4    93.84       2019   January
# 205      Natal 2019-01-02  196.09    1037     1   196.09       2019   January
# 78     Aracaju 2018-01-01  154.85    1522     9  1393.65       2018   January
# 62   Fortaleza 2019-01-01  106.21    1005     6   637.26       2019   January
#
#      Dia_Venda Diferenca_Dias  Trimestre_Venda
# 44     Tuesday       365 days                1
# 31     Tuesday       365 days                1
# 205  Wednesday       366 days                1
# 78      Monday         0 days                1
# 62     Tuesday       365 days                1

# %%
df['Trimestre_Venda'] = df['Data'].dt.quarter

df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda Mes_Venda  \
# 24   Fortaleza 2019-01-01   35.38    1005     4   141.52       2019   January
# 66     Aracaju 2018-01-01   76.59    1523     4   306.36       2018   January
# 39      Recife 2019-01-01  143.58     981     3   430.74       2019   January
# 53      Recife 2019-01-01   37.05     983     6   222.30       2019   January
# 172      Natal 2019-01-02    6.70    1035     1     6.70       2019   January
#
#      Dia_Venda Diferenca_Dias  Trimestre_Venda
# 24     Tuesday       365 days                1
# 66      Monday         0 days                1
# 39     Tuesday       365 days                1
# 53     Tuesday       365 days                1
# 172  Wednesday       366 days                1

# %%
vendas_marco_2019 = df.loc[(df['Data'].dt.year == 2019) & (df['Data'].dt.month == 3)]
vendas_marco_2019
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda Mes_Venda  \
# 108  Fortaleza 2019-03-02  152.89     981     4   611.56       2019     March
# 109  Fortaleza 2019-03-02   18.90     982     6   113.40       2019     March
# 110  Fortaleza 2019-03-02   51.98     983     6   311.88       2019     March
# 111  Fortaleza 2019-03-02    8.00     981     3    24.00       2019     March
# 112  Fortaleza 2019-03-02  133.59     982     1   133.59       2019     March
# ..         ...        ...     ...     ...   ...      ...        ...       ...
# 137   Salvador 2019-03-02   51.66    1036     3   154.98       2019     March
# 138   Salvador 2019-03-02  212.03    1037     3   636.09       2019     March
# 139   Salvador 2019-03-02  169.01    1036     1   169.01       2019     March
# 140   Salvador 2019-03-02   20.79    1036     2    41.58       2019     March
# 141   Salvador 2019-03-02    9.08    1036     1     9.08       2019     March
#
# ...

# %%
vendas_marco_2019.sort_values('Data')
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda Mes_Venda  \
# 108  Fortaleza 2019-03-02  152.89     981     4   611.56       2019     March
# 108   Salvador 2019-03-02   11.72    1037     1    11.72       2019     March
# 141     Recife 2019-03-02  182.75     983     8  1462.00       2019     March
# 140     Recife 2019-03-02  166.89     983     5   834.45       2019     March
# 139     Recife 2019-03-02  141.16     980     7   988.12       2019     March
# ..         ...        ...     ...     ...   ...      ...        ...       ...
# 46       Natal 2019-03-26  753.00     853     2  1506.00       2019     March
# 8        Natal 2019-03-27  667.00     852     4  2668.00       2019     March
# 75       Natal 2019-03-30  706.00     854     2  1412.00       2019     March
# 5        Natal 2019-03-30  674.00     854     2  1348.00       2019     March
# 19       Natal 2019-03-31  282.00     854     2   564.00       2019     March
#
# ...

# %% [markdown]
# # **Aula 4**

# %%
df['LojaID'].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df['LojaID'].value_counts(ascending=False).plot.bar()

# %%
df['LojaID'].value_counts(ascending=False).plot.barh()

# %%
df['LojaID'].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df['Data'].dt.year)['Receita'].sum().plot.pie()

# %%
df['Cidade'].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
df['Cidade'].value_counts().plot.bar(title='Total de vendas por cidade')
plt.xlabel('Cidade')
plt.ylabel('Total de vendas')
# Out:
# Text(0, 0.5, 'Total de vendas')

# %%
df['Cidade'].value_counts().plot.bar(title='Total de vendas por cidade', color='Red')
plt.xlabel('Cidade')
plt.ylabel('Total de vendas')
# Out:
# Text(0, 0.5, 'Total de vendas')

# %%
plt.style.use('dark_background')

# %%
df.groupby(df['Data'].dt.month-1)['Qtde'].sum().plot(title='Quantidade vendida por mês', color='Red')
plt.xlabel('Mês')
plt.ylabel('Quantidade vendida')
plt.legend(['Quantidade'])

months = ['Janeiro','Fevereiro','Março','Abril', 'Maio', 'Junho', 'Julho', 'Agosto','Setembro', 'Outubro', 'Novembro', 'Dezembro']
plt.xticks(range(len(months)), months, rotation=90);

# %%
vendas_2019 = df.loc[df['Ano_Venda'] == 2019]

vendas_2019.groupby(vendas_2019['Data'].dt.month-1)['Qtde'].sum().plot(title='Quantidade vendida por mês em 2019', color='Red', marker='o')
plt.xlabel('Mês')
plt.ylabel('Quantidade vendida')
plt.legend(['Quantidade'])

months_2019 = ['Janeiro','Fevereiro','Março','Abril']
plt.xticks(range(len(months_2019)), months_2019);

# %%
vendas_2019['Mes_Venda'].unique()
# Out:
# array(['January', 'February', 'March', 'April'], dtype=object)

# %%
#plt.hist(df['Qtde'], color='OrangeRed')
df['Qtde'].plot.hist(color='OrangeRed')

# %%
plt.scatter(x=vendas_2019['Data'].dt.day, y=vendas_2019['Receita'], color='Red')

# %%
vendas_2019 = df.loc[df['Ano_Venda'] == 2019]

vendas_2019.groupby(vendas_2019['Data'].dt.month-1)['Qtde'].sum().plot(title='Quantidade vendida por mês em 2019', color='Red', marker='o')
plt.xlabel('Mês')
plt.ylabel('Quantidade vendida')
plt.legend(['Quantidade'])

months_2019 = ['Janeiro','Fevereiro','Março','Abril']
plt.xticks(range(len(months_2019)), months_2019)
plt.savefig('Quantidade vendida por mês em 2019.png')

# %% [markdown]
# # **Aula 5**

# %%
plt.style.use('seaborn')

# %%
df = pd.read_excel('datasets/AdventureWorks.xlsx')
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
df.shape
# Out:
# (904, 16)

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# Receita total
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
df['Custo'] = df['Custo Unitário'] * df['Quantidade']
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro
# 0  Regular  Red  2091.48  2456.52

# %%
# Custo total
df['Custo'].sum()
# Out:
# 2486783.05

# %%
df['Lucro'] = df['Valor Venda'] - df['Custo']
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro
# 0  Regular  Red  2091.48  2456.52

# %%
# Lucro total
df['Lucro'].sum().round(2)
# Out:
# 3497823.09

# %%
df['Tempo de Envio'] = df['Data Envio'] - df['Data Venda']
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro Tempo de Envio
# 0  Regular  Red  2091.48  2456.52        20 days

# %%
df['Tempo de Envio'] = df['Tempo de Envio'].dt.days
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro  Tempo de Envio
# 0  Regular  Red  2091.48  2456.52              20

# %%
df['Tempo de Envio'].dtype
# Out:
# dtype('int64')

# %%
df.groupby('Marca')['Tempo de Envio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo de Envio, dtype: float64

# %%
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo de Envio    0
# dtype: int64

# %%
df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum().reset_index()
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False).reset_index()
# Out:
#                                            Produto  Quantidade
# 0  Headphone Adapter for Contoso Phone E130 Silver       25232
# 1   Headphone Adapter for Contoso Phone E130 White       25008
# 2          Adventure Works Laptop15.4W M1548 Black        1089
# 3        Fabrikam Trendsetter 2/3'' 17mm X100 Grey        1087
# 4            Adventure Works Laptop15.4W M1548 Red        1047
# 5       Fabrikam Trendsetter 2/3'' 17mm X100 Black         926
# 6      Fabrikam Trendsetter 1/3'' 8.5mm X200 Black         884
# 7       Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey         845
# 8      Fabrikam Trendsetter 1/3'' 8.5mm X200 White         789

# %%
df.groupby('Produto')['Quantidade'].sum().sort_values().plot.barh(title='Total Produtos Vendidos')
plt.xlabel('Total')
plt.ylabel('Produto')
# Out:
# Text(0, 0.5, 'Produto')

# %%
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum().plot.bar(title='Lucro por Ano')
plt.xlabel('Ano')
plt.ylabel('Lucro')
# Out:
# Text(0, 0.5, 'Lucro')

# %%
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: Lucro, dtype: float64

# %%
df_2009 = df.loc[df['Data Venda'].dt.year == 2009]
df_2009.head()
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 11 2009-05-02 2009-05-14      199         384       18938  200905023CS847
# 12 2009-05-16 2009-05-27      306         384       19067  200905163CS746
# 13 2009-05-31 2009-06-12      306         384       19068  200905313CS748
# 14 2009-06-28 2009-07-11      199         384       18959  200906283CS870
# 15 2009-07-08 2009-07-12      306         384       19070  200907083CS757
#
#          Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 11               348.58               758.00           6                 0.00
# 12               348.58               758.00           6                 0.00
# 13               348.58               758.00           6                 0.00
# 14               348.58               758.00           6                 0.00
# 15               348.58               758.00           6                 0.00
#
# ...

# %%
df_2009.groupby(df_2009['Data Venda'].dt.month)['Lucro'].sum().plot(title='Lucro por Mes em 2009')
plt.xlabel('Mes')
plt.ylabel('Lucro')
# Out:
# Text(0, 0.5, 'Lucro')

# %%
df_2009.groupby('Marca')['Lucro'].sum().plot.bar(title='Lucro por Marca em 2009')
plt.xlabel('Marca')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
df_2009.groupby('Classe')['Lucro'].sum().plot.bar(title='Lucro por Classe em 2009')
plt.xlabel('Classe')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
df['Tempo de Envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo de Envio, dtype: float64

# %%
plt.boxplot(df['Tempo de Envio'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f82f7bb4810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f82f7b24ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f82f72ee350>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f82f733ed10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f82f733ef90>],
#  'means': []}

# %%
df['Tempo de Envio'].plot.hist()

# %%
df.loc[df['Tempo de Envio'] == 20]
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
#
#            Valor Venda                                Produto  \
# 0             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#         Fabricante            Marca   Classe  Cor                Custo  \
# 0  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                  Lucro  Tempo de Envio
# 0             2,456.52              20

# %%
df.to_csv('df_vendas_novo.csv', index=False)
